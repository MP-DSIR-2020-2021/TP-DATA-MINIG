# %% [markdown]
# # Assignment Iris

# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
linkiris = {'iris': 'https://storage.googleapis.com/kagglesdsdata/datasets/19/420/Iris.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20201117%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20201117T142347Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...'}

# %%
iris = pd.read_csv(linkiris['iris'])
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Iris_setosa

# %%
Iris_setosa = iris[iris['Species'] == 'Iris-setosa']
Iris_setosa.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Iris_versicolor

# %%
Iris_versicolor = iris[iris['Species'] == 'Iris-versicolor']
Iris_versicolor.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
# 53  54            5.5           2.3            4.0           1.3
# 54  55            6.5           2.8            4.6           1.5
#
#             Species
# 50  Iris-versicolor
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor

# %% [markdown]
# ## Iris_virginica

# %%
Iris_virginica = iris[iris['Species'] == 'Iris-virginica']
Iris_virginica.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
#
#             Species
# 100  Iris-virginica
# 101  Iris-virginica
# 102  Iris-virginica
# 103  Iris-virginica
# 104  Iris-virginica

# %%
iris_sbn = sbn.load_dataset('iris')
iris_sbn.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
Iris_setosa_sepal_length = sbn.load_dataset('iris')
Iris_setosa_sepal_length.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ##  les relations entre les caractéristiques

# %%
sbn.pairplot(Iris_setosa_sepal_length, hue='species')

# %%
sbn.distplot(Iris_setosa_sepal_length['sepal_length'])

# %%
sbn.distplot(Iris_setosa_sepal_length['sepal_width'])

# %%
sbn.distplot(Iris_setosa_sepal_length['petal_length'])

# %%
sbn.distplot(Iris_setosa_sepal_length['petal_width'])

# %%
sbn.jointplot('sepal_length','sepal_width',Iris_setosa_sepal_length)

# %%
sbn.scatterplot(data=Iris_setosa_sepal_length, x="sepal_length", y="sepal_width", hue='species')

# %%
sbn.scatterplot(data=Iris_setosa_sepal_length, x="petal_length", y="petal_width", hue='species', style='species', palette='deep')
